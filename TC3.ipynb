# %% [markdown]
# # Trabajo Computacional 3

# %% [markdown]
# **1.**Considere la red social de 62 delfines de Nueva Zelanda (dolphins.txt, dolphins.gml, dolphinsGender.txt).

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import copy
import random
from __future__ import print_function
import community  #se usa para particion Louvain
import os
import numpy as np
import rpy2.robjects as robjects #se usa para infomap

# %%
def ldata(archive): #Leemos los archivos
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

G=nx.read_gml("dolphins.gml")
genero=ldata("dolphinsGender.txt")

# %% [markdown]
# Definimos funciones que usaremos para evaluar las particiones

# %%
#Esto lo usamos para calcular modularidad 
import time

def calculate_infomap(np_adj_list, method="infomap"):
    g = igraph.Graph.Weighted_Adjacency(np_adj_list.tolist(),mode=igraph.ADJ_UPPER)
   
    t0=time.time()
    if method=="infomap":
        labels = g.community_infomap(edge_weights="weight").membership
#    labels = g.community_label_propagation(weights="weight").membership
    if method=="fastgreedy":
        labels = g.community_fastgreedy(edge_weights="weight").membership
   
    print("Duración: {}s".format(time.time()-t0))
           
    return labels

from __future__ import division

from functools import wraps
from itertools import product

import networkx as nx
from networkx import NetworkXError
from networkx.utils import not_implemented_for
from networkx.algorithms.community.community_utils import is_partition

__all__ = ['coverage', 'modularity', 'performance']


class NotAPartition(NetworkXError):
    """Raised if a given collection is not a partition.

    """

    def __init__(self, G, collection):
        msg = '{} is not a valid partition of the graph {}'
        msg = msg.format(G, collection)
        super(NotAPartition, self).__init__(msg)


def modularity(G, communities, weight='weight'):
    r"""Returns the modularity of the given partition of the graph.

    Modularity is defined in [1]_ as

    .. math::

        Q = \frac{1}{2m} \sum_{ij} \left( A_{ij} - \frac{k_ik_j}{2m}\right)
            \delta(c_i,c_j)

    where $m$ is the number of edges, $A$ is the adjacency matrix of
    `G`, $k_i$ is the degree of $i$ and $\delta(c_i, c_j)$
    is 1 if $i$ and $j$ are in the same community and 0 otherwise.

    Parameters
    ----------
    G : NetworkX Graph

    communities : list
        List of sets of nodes of `G` representing a partition of the
        nodes.

    Returns
    -------
    Q : float
        The modularity of the paritition.

    Raises
    ------
    NotAPartition
        If `communities` is not a partition of the nodes of `G`.

    Examples
    --------
    >>> G = nx.barbell_graph(3, 0)
    >>> nx.algorithms.community.modularity(G, [{0, 1, 2}, {3, 4, 5}])
    0.35714285714285704

    References
    ----------
    .. [1] M. E. J. Newman *Networks: An Introduction*, page 224.
       Oxford University Press, 2011.

    """
    if not is_partition(G, communities):
        raise NotAPartition(G, communities)

    multigraph = G.is_multigraph()
    directed = G.is_directed()
    m = G.size(weight=weight)
    if directed:
        out_degree = dict(G.out_degree(weight=weight))
        in_degree = dict(G.in_degree(weight=weight))
        norm = 1 / m
    else:
        out_degree = dict(G.degree(weight=weight))
        in_degree = out_degree
        norm = 1 / (2 * m)

    def val(u, v):
        try:
            if multigraph:
                w = sum(d.get(weight, 1) for k, d in G[u][v].items())
            else:
                w = G[u][v].get(weight, 1)
        except KeyError:
            w = 0
        # Double count self-loops if the graph is undirected.
        if u == v and not directed:
            w *= 2
        return w - in_degree[u] * out_degree[v] * norm

    Q = sum(val(u, v) for c in communities for u, v in product(c, repeat=2))
    return Q * norm

# %%
#Funciones para calcular Silhouette
def Silhouette1(lista,G):# para la primera partición, primer cluster
    F=lista[0] #primera partición
    b=[]
    a=[]
    S=[]
    for i in F[0]: #F0 es primer cluster, i nodo de ese cluster
        A=[]
        for j in F[0]:
            if i!=j:
                A.append(nx.shortest_path_length(G, source=i, target=j, weight=None))
        a.append(sum(A)/len(A))
        B=[]
        for k in F[1]: #F1 es el segundo cluster, k nodo
            B.append(nx.shortest_path_length(G, source=i, target=k, weight=None))
        b.append(sum(B)/len(B))
    for i in range(len(a)):
        m=max(a[i],b[i])
        s=(b[i]-a[i])/m
        S.append(s)
    return S #es una lista que contiene los valores de Silhouette por nodo del primer cluster de una partición

# %%
def Silhouette(lista,G): #La función más general para calcular Silhouette
    S=[]
    for l in range(len(lista)-1):  # me muevo en particiones 
        F=lista[l] # es la partición l-ésima
        S_l=[] #lista de silhouette para la partición l
        for c in range(len(F)):    # me muevo en cluster dentro de esa partición
            b=[]
            a=[]
            S_c=[]  #lista de silhouette para el cluster c de la partición l
            for i in F[c]: # me muevo dentro del cluster c, i nodo
                A=[]
                for j in F[c]:
                    if i!=j:
                        A.append(nx.shortest_path_length(G, source=i, target=j, weight=None))
                if len(A)!=0:
                    a.append(sum(A)/len(A))
                b1=[]
                for k in range(len(F)):
                      if k!=c:
                        B=[]
                        for z in F[k]: # me muevo dentro del cluster k
                            B.append(nx.shortest_path_length(G, source=i, target=z, weight=None))
                        b1.append(sum(B)/len(B))
                b.append(min(b1))
            for i in range(len(a)):
                m=max(a[i],b[i])
                s=(b[i]-a[i])/m
                S_c.append(s)
            S_l.append(S_c)
        S.append(S_l)
    return S #tengo una lista (todas las particiones) de listas (clusters) de listas (nodos)

# %%
def Silhouette2(lista,G): #Para una única partición
    S_l=[] #lista de silhouette para la partición l
    for c in range(len(lista)):    # me muevo en cluster dentro de esa partición
        b=[]
        a=[]
        S_c=[]  #lista de silhouette para el cluster c de la partición l
        for i in lista[c]: # me muevo dentro del cluster c, i nodo
            A=[]
            for j in lista[c]:
                if i!=j:
                    A.append(nx.shortest_path_length(G, source=i, target=j, weight=None))
            if len(A)!=0:
                a.append(sum(A)/len(A))
            b1=[]
            for k in range(len(lista)):
                  if k!=c:
                    B=[]
                    for z in lista[k]: # me muevo dentro del cluster k
                        B.append(nx.shortest_path_length(G, source=i, target=z, weight=None))
                    b1.append(sum(B)/len(B))
            b.append(min(b1))
        for i in range(len(a)):
            m=max(a[i],b[i])
            s=(b[i]-a[i])/m
            S_c.append(s)
        S_l.append(sorted(S_c))
    return S_l

# %% [markdown]
# **a.** Encuentre la partición en clusters de esta red utilizando la metodología Louvain, infomap, fast_greedy y edge_betweenness. Visualice los resultados gráficamente.

# %% [markdown]
# # Edge betweenness

# %% [markdown]
# Este algoritmo es divisivo, parte de toda la red como una comunidad y luego va separando comunidades hasta llegar a tener a cada nodo como una comunidad. El código usado devuelve todas las particiones posibles arrojadas por el método. Se elegirá la partición con modularidad máxima.

# %%
#edge-betweenness
com = nx.algorithms.community.centrality.girvan_newman(G)
a=[nodos for nodos in com] #lista con todas las particiones del método
#La primera comunidad ya es de dos clusters

# %%
modular=[] #creamos una lista de modularidades para las particiones
for i in range(len(a)):
    modular.append([modularity(G,[cluster for cluster in a[i]]),i]) #También guardamos la posición en la lista, lo que está asociado al número de clusters en la partición
    #La partición 0 tiene 2 clusters, la 1 tiene 3 comunidades y así..

# %%
Modularidades_ordenadas=sorted(modular,reverse=True) # La ordenamos, nos vamos a quedar con la primera de la nueva lista. 
Modularidades_ordenadas[0] #Es la partición con la que vamos a trabajar
# Out:
# [0.5193821446936427, 3]

# %% [markdown]
# El método Edge-Betweenness arroja una partición con cinco comunidades (es el tercer elemento de la lista de particiones total)

# %%
Cluster=[] #la particion con más modularidad de edge betweeness
b=0
Color=["r","g","b","y","c"] #Vamos a asignarle un color a cada cluster-sabemos que hay cinco-
for c in a[3]:
    for n in a[3][b]:
        Cluster.append([n,Color[b]])
        
    b+=1
Cluster=sorted(Cluster) #Ordenamos

# %%
dict={} #Creamos un diccionario para cada nodo da su color
for i in Cluster:
    dict[i[0]]=i[1]

# %%
#Vemos en forma gráfica como es la patición
nx.draw(G,  with_labels=False,
        node_color=list(dict.values()),
        node_size=500,
        alpha=1) #Usamos el diccionario creado anteriormente
plt.title("Red de delfines, color asociado a la comunidad dada por Edge-Betweenness")
plt.show()

# %%
F=[]                    ##F va a ser el nuevo vector de nodo-cluster pero ordenando los nodos de la misma manera que lo hace nx
for n in G.nodes():
    for k in Cluster:
        if k[0]==n:
            F.append([k[0],k[1]])

# %%
#Calculamos Silhouette de todas las particiones
S=Silhouette(a,G)

# %%
#Elegimos la partición más modular
SilE=Silhouette2(a[3],G)
SilouE=[] 
SCE=[]
Color=["r","g","b","y","m"]
b=0
for i in SilE: # i es un cluster
    for j in i: #j es un nodo del cluster i 
        SCE.append(Color[b]) #Doy el color de cada nodo según el cluster
        SilouE.append(j) #Creamos una lista que tenga todos los nodos 
    b+=1

# %%
# Graficando silhouette Edge betweenness partición numero 3 (la de mayor modularidad)
plt.rcdefaults()
fig, ax = plt.subplots()


y_pos = np.arange(1,63)
sil= SilouE
ax.barh(y_pos, sil, align='center',
        color=SCE) #cada barra es el valor de silhouette de cada nodo, color asociado a qué cluster pertenece

plt.axvline(sum(sil)/len(sil),c="k",label='Silhouette promedio') #Agregamos la línea con el valor promediado sobre la red
plt.legend()
plt.xlabel('Silhouette')
plt.title("Método de detección:Edge-Betweenness")
plt.show()

# %% [markdown]
# Vamos a analizar cómo es cada cluster, en términos de su Silhouette promedio para ver cuan buena es la partición

# %%
S=[]
for i in range(len(SilE)):
    S.append(sum(SilE[i]))
Silhouette_EB=sum(S)/62
Silhouette_EB #Silhouette promedio para la partición de mayor modularidad
# Out:
# 0.28762733242788757

# %%
#Silhouette por cluster
Silhouette_EB_xcluster=[]
for i in range(len(SilE)):
    Silhouette_EB_xcluster.append(sum(SilE[i])/len(SilE[i]))
Silhouette_EB_xcluster
# Out:
# [0.34866083273408466,
#  0.388600145524721,
#  0.0962444488724075,
#  0.3407426520146554,
#  0.6089324618736384]

# %%
#Calculamos la distancia del valor de cada cluster al promedio global y lo pesamos en término de este último
DE=[]
for i in Silhouette_EB_xcluster:
    DE.append(np.absolute(i-Silhouette_EB)/Silhouette_EB)
DE
# Out:
# [0.21219645501353418,
#  0.351054304347619,
#  0.665384899063661,
#  0.18466714946182886,
#  1.1170883056682617]

# %%
print(len(SilE[0]),len(SilE[1]),len(SilE[2]),len(SilE[3]),len(SilE[4])) #Tamaños de los clusters de la partición
#Suman 62 nodos en total
# Out:
# 7 21 20 12 2

# %%
#Vamos a graficar el valor medio de silhouette en cada cluster y el valor global.
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(1,6)
sil= Silhouette_EB_xcluster    
ax.barh(y_pos, sil, align='center',
        color="b")

plt.axvline(Silhouette_EB,c="k", label='Silhouette promedio total')
plt.ylabel("Clusters de la partición de mayor modularidad")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Edge-Betweenness")
plt.legend(loc=0)
plt.show()
#No podemos identificar cuál es cada cluster.. Probemos otra cosa

# %%
#Usamos el tamaño de cada cluster para identificarlo
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.array([21,20,7,12,2]) #Estan ordenados como la lista
sil= Silhouette_EB_xcluster    
ax.barh(y_pos, sil, 
        color="b")

plt.axvline(Silhouette_EB,c="k", label='Silhouette promedio total')
plt.ylabel("Clusters de la partición de mayor modularidad")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Edge-Betweenness")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# Veamos como es la distribución de valores.

# %%
b=62
#edge_betweenness
plt.hist(SilouE,bins=b)
plt.axvline(Silhouette_EB,c="r",label="Silhouette promedio")
plt.title("Distribución de Silhouette: Edge-Betweenness")
plt.xlabel("Silhouette")
plt.legend()
plt.show()

# %% [markdown]
# No da información representativa, no lo incluiremos en el informe.

# %% [markdown]
# # Louvain

# %%
# Louvain
partition = community.best_partition(G) #El método ya elige la mejor partición

# %%
nx.draw(G,
        cmap=plt.get_cmap('plasma'),
        node_color=list(partition.values()),
        node_size=500,
        alpha=1) #Usamos la partición para que nos de el color del nodo según el cluster al que pertenece
plt.title("Red de delfines, color asociado a la comunidad dada por el método Louvain")
plt.show()

# %%
o=[]
for j in G.nodes():
    o.append(partition[j])
set(o) #Da el índice de clusters
# Out:
# {0, 1, 2, 3, 4}

# %%
cluster=[0,1,2,3,4] #Hay cinco clusters
A=[] #armamos la lista de la partición a partir de Louvain
for i in cluster:
    a=[]
    for j in G.nodes():
        if partition[j]==i:
            a.append(j)
    A.append(a)
type(A)
# Out:
# list

# %%
k=0 #Chequeamos que estén todos los nodos
for i in A:
    for j in i:
        k+=1
k
# Out:
# 62

# %%
modularity(G,[cluster for cluster in A]) #Louvain modularidad
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-40cbde2cc1d5> in <module>()
# ----> 1 modularity(G,[cluster for cluster in A]) #Louvain modularidad
#
# <ipython-input-3-203df02db034> in modularity(G, communities, weight)
#      95         norm = 1 / m
#      96     else:
# ---> 97         out_degree = dict(G.degree(weight=weight))
#      98         in_degree = out_degree
#      99         norm = 1 / (2 * m)
#
# TypeError: 'dict' object is not callable

# %%
#Calculamos el valor de Silhouette para cada nodo.
SilL=Silhouette2(A,G)
SilouL=[]
SCL=[]
Color=["r","g","b","y","m","c"] #Definimos un color para cada cluster
b=0
for i in SilL:
    for j in i:
        SCL.append(Color[b])
        SilouL.append(j)
    b+=1

# %%
k=0 #chequeo de rutina
for j in SilL:
    for i in j:
        k+=1
k
# Out:
# 62

# %%
PromedioL=sum(SilouL)/len(SilouL) #Valor de silhouette promedio

# %%
# Graficando silhouette Louvain
plt.rcdefaults()
fig, ax = plt.subplots()


y_pos = np.arange(1,63)
sil= SilouL
ax.barh(y_pos, sil, align='center',
        color=SCL)

plt.axvline(sum(sil)/len(sil),c="k",label='Silhouette promedio')
plt.title('Método de detección: Louvain')
plt.xlabel('Valores de Silhouette')
plt.legend(loc=2)
plt.show()

# %%
Silhouette_L_xcluster=[] #Promediamos Silhouette en cada cluster
for i in range(len(SilL)):
    Silhouette_L_xcluster.append(sum(SilL[i])/len(SilL[i]))
Silhouette_L_xcluster
# Out:
# [0.29486732278245764,
#  0.34013486972716694,
#  0.17239308498519026,
#  0.3185756610534733,
#  0.1655255692020398]

# %%
DE_L=[] #Vemos cuanto distan del valor global, pesado en términos de éste último.
for i in Silhouette_L_xcluster:
    DE_L.append(np.absolute(i-PromedioL)/PromedioL)
DE_L
# Out:
# [0.12033765807896338,
#  0.2923300547014633,
#  0.34499874967899957,
#  0.2104166262225088,
#  0.3710916258807868]

# %%
print(len(SilL[0]),len(SilL[1]),len(SilL[2]),len(SilL[3]),len(SilL[4])) #Tamaño de clusters, suman 62
# Out:
# 8 18 6 12 18

# %%
#Vemos como es el valor promedio sobre cada cluster
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(1,6)
sil= Silhouette_L_xcluster    
ax.barh(y_pos, sil, align='center',
        color="g")

plt.axvline(sum(SilouL)/len(SilouL),c="k", label='Silhouette promedio total')
plt.ylabel("Clusters de la partición de mayor modularidad")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Louvain")
plt.legend(loc=0)
plt.show()

# %%
#Lo mismo pero distinguimos el cluster por su tamaño
plt.rcdefaults()
fig, ax = plt.subplots()


y_pos = np.array([20,18,7,12,5])
sil= Silhouette_L_xcluster    
ax.barh(y_pos, sil, align='center',
        color="g")

plt.axvline(sum(SilouL)/len(SilouL),c="k", label='Silhouette promedio total')
plt.ylabel("Tamaño del cluster")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Louvain")
plt.legend(loc=0)
plt.show()

# %%
#Distribución de Silhouette, no parece dar mucha info
sil= SilouL
b=50
#louvain
plt.hist(sil,bins=b)
plt.axvline(sum(SilouL)/len(SilouL),c="r",label="Silhouette promedio")
plt.title("Distribución de Silhouette: Louvain")
plt.xlabel("Valores de Silhouette")
plt.legend()
plt.show()

# %% [markdown]
# # Fast Greedy

# %%
comus = nx.algorithms.community.greedy_modularity_communities(G, weight=None) #El código ya da una única partición
type(comus)
# Out:
# list

# %%
B=[] #Partición obtenida con fastgreedy
for j in comus:
    a=[]
    for i in j:
        a.append(i)
    B.append(a)
#Me genero una lista de listas, separando nodos por cluster

# %%
len(B) #Da número de clusters
# Out:
# 4

# %%
ClusterF=[] 
b=0
Color=["r","g","b","y","k"] #Asigno color
for c in B:
    for n in B[b]:
        ClusterF.append([n,Color[b]])
        
    b+=1
ClusterF=sorted(ClusterF) #para el grafo, el orden alfabetico es el de G.nodes

# %%
dictF={} #Me genero un diccionario con el color por cluster
for i in ClusterF:
    dictF[i[0]]=i[1]

# %%
nx.draw(G,  with_labels=False,
        cmap=plt.get_cmap('plasma'),
        node_color=list(dictF.values()),
        node_size=500,
        alpha=1) #uso el diccionario para asignar color
plt.title("Red de Delfines, colores asociados a una comunidad dada por método de Fast Greedy")
plt.show()

# %%
modularity(G,[cluster for cluster in B]) #Fastgreedy modularidad
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-3f3bec9cf205> in <module>()
# ----> 1 modularity(G,[cluster for cluster in B]) #Fastgreedy modularidad
#
# <ipython-input-3-203df02db034> in modularity(G, communities, weight)
#      95         norm = 1 / m
#      96     else:
# ---> 97         out_degree = dict(G.degree(weight=weight))
#      98         in_degree = out_degree
#      99         norm = 1 / (2 * m)
#
# TypeError: 'dict' object is not callable

# %%
SilF=Silhouette2(B,G) #Calculamos Silhouette para cada nodo
SilouF=[] #Todos los nodos
SCF=[] #lista de colores para los nodos según cluster
Color=["r","g","b","y"]
b=0
for i in SilF:
    for j in i:
        SCF.append(Color[b])
        SilouF.append(j)
    b+=1

# %%
sum(SilouF)/len(SilouF) #Valor de Silhouette promedio total
# Out:
# 0.1379546327967556

# %%
# Graficando silhouette Fastgreedy
plt.rcdefaults()
fig, ax = plt.subplots()


y_pos = np.arange(1,63)
sil= SilouF
ax.barh(y_pos, sil, align='center',
        color=SCF)

plt.axvline(sum(sil)/len(sil),c="k",label='Silhouette promedio')
plt.legend()
plt.xlabel("Valores de Silhouette")
plt.title('Método de detección:Fast Greedy')
plt.show()

# %%
Silhouette_FG_xcluster=[] #Calculo el promedio por cluster
for i in range(len(SilF)):
    Silhouette_FG_xcluster.append(sum(SilF[i])/len(SilF[i]))
Silhouette_FG_xcluster
# Out:
# [0.11220658367187186,
#  0.08253439399109476,
#  0.1995749630386182,
#  0.5815273477812177]

# %%
print(len(SilF[0]),len(SilF[1]),len(SilF[2]),len(SilF[3]))  #Tamaño de cada cluster
# Out:
# 23 22 15 2

# %%
fg=sum(SilouF)/len(SilouF) #Valor promedio sobre la red

# %%
DE_F=[] #Calculo cuanto distan los promedios por cluster del valor global, pesado por este último
for i in Silhouette_FG_xcluster:
    DE_F.append(np.absolute(i-fg)/fg)
DE_F
# Out:
# [0.18664142408916098,
#  0.40172800059067104,
#  0.446670974309692,
#  3.2153520762000394]

# %%
#Graficamos el valor promediado sobre cada cluster.
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(1,5)
sil= Silhouette_FG_xcluster    
ax.barh(y_pos, sil, align='center',color='c')

plt.axvline(fg,c="k", label='Silhouette promedio total')
plt.ylabel("Clusters ")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Fast Greedy")
plt.legend(loc=0)
plt.show()

# %%
#Vemos lo mismo pero en función al número de nodos de cada cluster
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.array([24,21,15,2])
sil= Silhouette_FG_xcluster    
ax.barh(y_pos, sil, align='center',color='c')

plt.axvline(fg,c="k", label='Silhouette promedio total')
plt.ylabel("Tamaño del cluster")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Fast Greedy")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# # Infomap

# %%
#Función para infomap
def community(nxG, algorithm, fig_name = "G"):
    """
    In:
        nxG: grafo de networkx.
        algorithm: string, entre las siguientes opciones: 
            fast_greedy
            edge_betweenness
            louvain
            infomap
        fig_name: nombre de la figura que se genera al clsuterizar. Le agrega automaticamente el nombre del algoritmo usado y el nombre del grafo si lo tuviere
    Out:
        labels: numpy array con la pertenencia de cada nodo al cluster.
    
    """
    gml_file_name = "G.gml"
    fig_name += "_"+nxG.name+"_"+algorithm+".svg"
    nx.write_gml(nxG, gml_file_name)
    
    igG = robjects.r('''
        f <- function(file, algorithm, fig_name){
            require("igraph")     
            
            G <- read.graph(file, "gml")
            #format = c("edgelist", "pajek", "ncol", "lgl", "graphml","dimacs", "graphdb", "gml", "dl"), ...)
            
            if(algorithm == "fast_greedy"){
                c <- fastgreedy.community(G)
                #c <- cluster_fast_greedy(G, merges = TRUE, modularity = TRUE, membership = TRUE)
            }
            
            if(algorithm == "edge_betweenness"){
                c <- edge.betweenness.community(G)
                #c <- cluster_edge_betweenness(G,directed = FALSE,edge.betweenness = TRUE)
            }
            
            if(algorithm == "louvain"){
                c <- multilevel.community(G)
                #c <- cluster_louvain(G)
            }
            
            if(algorithm == "infomap"){
                #c <- cluster_infomap(G)
                c <- infomap.community(G)
            }
            
            svg(fig_name)
            plot(c, G)
            dev.off()
            
            return(membership(c))
        }
    ''')
    
    labels = igG(gml_file_name, algorithm, fig_name)
    os.remove(gml_file_name)
    return np.array(labels)

# %%
Z=community(G, "infomap", fig_name = "G") #Partición para infomap
# Out:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-57-616a416a60a7> in <module>()
# ----> 1 Z=community(G, "infomap", fig_name = "G") #Partición para infomap
#
# <ipython-input-56-fe3578d20c0c> in community(nxG, algorithm, fig_name)
#      53     ''')
#      54
# ---> 55     labels = igG(gml_file_name, algorithm, fig_name)
#      56     os.remove(gml_file_name)
#      57     return np.array(labels)
#
# ~\Anaconda3\lib\site-packages\rpy2-2.9.4-py3.6-win-amd64.egg\rpy2\robjects\functions.py in __call__(self, *args, **kwargs)
#     176                 v = kwargs.pop(k)
#     177                 kwargs[r_k] = v
# --> 178         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     179
#     180 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# ...

# %%
ClusterNodo=[] #Genero una lista con el nombre del nodo y el cluster al que pertenece
m=0
for i in G.nodes():
    ClusterNodo.append([Z[m],i])
    m+=1
sorted(ClusterNodo)

C=[] #lista con el numero de cluster
for i in set(Z):
    c=[]
    for k in ClusterNodo:
        if k[0]==i:
            c.append(k[1])
    C.append(c)

# %%
SilI=Silhouette2(C,G) #Calculo Silhouette para la partición
SilouI=[] #Todos los valores de los nodos
SCI=[] #Asigno color por cluster
Color=["r","g","b","y","m","c"]
b=0
for i in SilI:
    for j in i:
        SCI.append(Color[b])
        SilouI.append(j)
    b+=1

# %%
sum(SilouI)/len(SilouI) #Promedio nodos
# Out:
# 0.2663593908420002

# %%
# Graficando siloutte Infomap
plt.rcdefaults()
fig, ax = plt.subplots()


y_pos = np.arange(1,63)
sil= SilouI
ax.barh(y_pos, sil, align='center',
        color=SCI)

plt.axvline(sum(sil)/len(sil),c="k",label='Silhouette promedio')
plt.legend()
plt.xlabel("Valores de Silhouette")
plt.title('Método de detección:Infomap')
plt.show()

# %%
#Grafo coloreado
nx.draw(G,
        cmap=plt.get_cmap('plasma'),
        node_color=Z,
        node_size=500,
        alpha=1)
plt.title('Red de Delfines, colores asociados a una comunidad dada por método de Fast Greedy')
plt.show()
# Out:
# /home/candesz/.local/lib/python3.5/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
Silhouette_I_xcluster=[] #Silhouette por cluster
for i in range(len(SilI)):
    Silhouette_I_xcluster.append(sum(SilI[i])/len(SilI[i]))
Silhouette_I_xcluster
# Out:
# [0.31840256238335246,
#  0.11857072426671816,
#  0.28815251201614833,
#  0.315403379689094,
#  0.238989898989899,
#  0.5989956958393113]

# %%
DE_I=[] #Desviación de valor medio global pesado por este último
for i in Silhouette_I_xcluster:
    DE_I.append(np.absolute(i-sum(SilouI)/len(SilouI))/(sum(SilouI)/len(SilouI)))
DE_I
# Out:
# [0.19538703470088406,
#  0.5548468409846594,
#  0.08181848255943569,
#  0.18412712497974518,
#  0.10275399626640656,
#  1.248825145401482]

# %%
print(len(SilI[0]),len(SilI[1]),len(SilI[2]),len(SilI[3]),len(SilI[4]),len(SilI[5])) #Tamaños
# Out:
# 20 16 12 7 5 2

# %%
#Grafico Silhouette por nodo, identificando a qué cluster pertenece
plt.rcdefaults()
fig, ax = plt.subplots()


y_pos = np.arange(1,7)
sil= Silhouette_I_xcluster    
ax.barh(y_pos, sil, align='center',
        color="y")

plt.axvline(sum(SilouI)/len(SilouI),c="k", label='Silhouette promedio total')
plt.ylabel("Clusters ")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Infomap")
plt.legend(loc=0)
plt.show()

# %%
#Identifico por tamaño
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.array([20,16,12,7,5,2])
sil= Silhouette_I_xcluster    
ax.barh(y_pos, sil, align='center',
        color="y")

plt.axvline(sum(SilouI)/len(SilouI),c="k", label='Silhouette promedio total')
plt.ylabel("Tamaño del Cluster")
plt.xlabel("Silhouette promedio del cluster")
plt.title("Método de detección: Infomap")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# **b.** Caracterice  las  particiones  obtenidas  en  términos  de  modularidad  y  silouhette
# de  cada partición. Compare con valores esperados en redes recableadas y establezca si tiene derecho a
# llamar modular a esta red.

# %%
import igraph as igraph
def clusterize(nx_Graph, method="infomap"): ##Me anduvo esto
    """
    Calcula el agrupamiento en comunidades de un grafo.
    
    In:
        nx_Graph: grafo de networkx
        method: metodo de clustering, puede ser: "infomap", "fastgreedy", "eigenvector", "louvain", "edge_betweenness","label_prop", "walktrap", ""
        
    Out:
        labels_dict: diccionario de nodo : a label al cluster al que pertenece.
    """
    if method == "edge_betweenness":
        nx_Graph = max(nx.connected_component_subgraphs(nx_Graph), key=len)#se queda con la componente más grande.
        print("AVISO: restringiendo a la componente connexa más grade. De otro modo falla el algoritmo de detección de comunidades edge_betweenness.")
    
    isdirected = nx.is_directed(nx_Graph)
    np_adj_list = nx.to_numpy_matrix(nx_Graph)
    g = igraph.Graph.Weighted_Adjacency(np_adj_list.tolist(),mode=igraph.ADJ_UPPER)
   
    if method=="infomap":
        labels = g.community_infomap(edge_weights="weight").membership
    if method=="label_prop":
        labels = g.community_label_propagation(weights="weight").membership
    if method=="fastgreedy":
        labels = g.community_fastgreedy(weights="weight").as_clustering().membership
    if method=="eigenvector":
        labels = g.community_leading_eigenvector(weights="weight").membership
    if method=="louvain":
        labels = g.community_multilevel(weights="weight").membership
    if method=="edge_betweenness":
        labels = g.community_edge_betweenness(weights="weight", directed=isdirected).as_clustering().membership
    if method=="walktrap":
        labels = g.community_walktrap(weights="weight").as_clustering().membership
    
    label_dict = {node:label for node,label in zip(nx_Graph.nodes(), labels)}
    return label_dict

# %%
def recableo(Grafo): #Recableo al intercambiar enlaces, evito selfloops
    b=160
    nx.double_edge_swap(Grafo,nswap=b,max_tries=3*b)
    return Grafo

# %%
def modularidad_recableada(Grafo,metodo,iteraciones): #Calculo la modularidad para la red recableada, según cada método
    mod=[]
    for i in range(iteraciones):
        Gr=copy.deepcopy(Grafo)
        recableo(Gr) #Recableo de la red (dado por la función recableo)
        
        #modularidad Edge_betweenness
        if metodo=="edge_betweenness":
            com = nx.algorithms.community.centrality.girvan_newman(Gr) #doy la partición
            a=[nodos for nodos in com]
            modular=[]
            for i in range(len(a)):
                modular.append(modularity(Gr,[cluster for cluster in a[i]]))
            mod.append(sorted(modular,reverse=True)[0])
        
        #modularidad Louvain    
        if metodo=="louvain":
            partition = community.best_partition(Gr)
            A=[] #armamos la lista de la partición a partir de Louvain           
            for i in set(partition.values()):
                a=[]
                for j in Gr.nodes():
                    if partition[j]==i:
                        a.append(j)
                A.append(a)
            mod.append(modularity(Gr,[cluster for cluster in A]))
        
        #modularidad Fastgreedy
        if metodo=="fastgreedy":
            comus = nx.algorithms.community.greedy_modularity_communities(Gr, weight=None)
            B=[] #Partición obtenida con fastgreedy
            for j in comus:
                a=[]
                for i in j:
                    a.append(i)
                B.append(a)
            mod.append(modularity(Gr,[cluster for cluster in B]))
        
        #modularidad Infomap
        if metodo=="infomap":                        
            partition = clusterize(Gr, "infomap")
            C=[] #armamos la lista de la partición a partir de infomap
            for i in set(partition.values()):
                a=[]
                for j in Gr.nodes():
                    if partition[j]==i:
                        a.append(j)
                C.append(a)
            mod.append(modularity(Gr,[cluster for cluster in C]))

    return mod

# %%
#Lista de posibles modularidades para meter en modularidad_recableada
metodo=["edge_betweenness","louvain","fastgreedy","infomap"]

# %%
def creartxt(lista1,lista2,lista3,lista4,NombreArchivo):         ##Lo único que hay que decirle es las dos listas a guardar. Se podrían guardar más, pero hace falta agregar un par de cosas
    with open(NombreArchivo,'w') as f:             ##Nombre de archivo hay que ponerlo entre comillas y punto txt. Es el nombre que queremos que tenga el archivo
        a=0
        for item in lista1:
            f.write("{}\t{}\t{}\t{}\n".format(item,lista2[a],lista3[a],lista4[a]))
            a+=1
            
#LECTURA Para trabajar con los archivos txt de la carpeta           
def leetxt(NombreArchivo):    ##Le ponés entre comillas y .txt el nombre del archivo y lo lee
    lectura1=[]               ##la función devuelve dos listas. la primera es la lista1 de arriba, la segunda la lista2
    lectura2=[]               ##Para aplicarla es poner f=leetxt("NombreArchivo.txt")
    lectura3=[]
    lectura4=[]
    with open(NombreArchivo, 'r') as f: ## f[0] va a ser lista1
        contenido= f.readlines()        ## f[1] va a ser lista2
        for x in contenido:             ## Al igual que la de arriba se puede extender fácil a más de dos listas
            row = x.split()
            lectura1.append(float(row[0]))
            lectura2.append(float(row[1]))
            lectura3.append(float(row[2]))
            lectura4.append(float(row[3]))
    return lectura1, lectura2, lectura3, lectura4

# %%
#armo el for para correr en los cuatro métodos
H=[] #va a contener la lista de modularidades random para cada uno de los metodos
for i in metodo:
    H.append(modularidad_recableada(G,i,1000))
creartxt(H[0],H[1],H[2],H[3],"Modularidades.txt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-19f9208a705a> in <module>()
#       2 H=[] #va a contener la lista de modularidades random para cada uno de los metodos
#       3 for i in metodo:
# ----> 4     H.append(modularidad_recableada(G,i,1000))
#       5 creartxt(H[0],H[1],H[2],H[3],"Modularidades.txt")
#
# <ipython-input-60-e8ce6dee9b98> in modularidad_recableada(Grafo, metodo, iteraciones)
#      11             modular=[]
#      12             for i in range(len(a)):
# ---> 13                 modular.append(modularity(Gr,[cluster for cluster in a[i]]))
#      14             mod.append(sorted(modular,reverse=True)[0])
#      15
#
# <ipython-input-3-203df02db034> in modularity(G, communities, weight)
#      95         norm = 1 / m
#      96     else:
# ---> 97         out_degree = dict(G.degree(weight=weight))
#      98         in_degree = out_degree
# ...

# %%
H=leetxt("Modularidades.txt")

# %%
LISTAH=list(H)
len(H[0]) #da el número de iteraciones
# Out:
# 1000

# %%
partition = clusterize(G, "infomap")
C=[] #armamos la lista de la partición a partir de infomap
for i in set(partition.values()):
    a=[]
    for j in G.nodes():
        if partition[j]==i:
            a.append(j)
    C.append(a)
modularity(G,[cluster for cluster in C])
# Out:
# 0.5277283335311076

# %%
#graficamo las modularidades
b=50
#edge_betweenness
plt.title("Distribución de modularidad para recableados aleatorios")
plt.xlabel("Modularidad")
plt.ylabel("Ocurrencia")
plt.hist(H[0],bins=b,label="Distribución aleatoria")
plt.axvline(0.5193,c="r",label="Valor real")
plt.legend()
plt.show()
#louvain
plt.title("Distribución de modularidad para recableados aleatorios")
plt.xlabel("Modularidad")
plt.ylabel("Ocurrencia")
plt.hist(H[1],bins=b,label="Distribución aleatoria")
plt.axvline(0.5277,c="r",label="Valor real")
plt.legend()
plt.show()
#fastgreedy
plt.xlabel("Modularidad")
plt.ylabel("Ocurrencia")
plt.title("Distribución de modularidad para recableados aleatorios")
plt.hist(H[2],bins=b,label="Distribución aleatoria")
plt.axvline(0.492,c="r",label="Valor real")
plt.legend()
plt.show()
#infomap
plt.xlabel("Modularidad")
plt.ylabel("Ocurrencia")
plt.title("Distribución de modularidad para recableados aleatorios")
plt.hist(H[3],bins=b,label="Distribución aleatoria")
plt.axvline(0.5277,c="r",label="Valor real")
plt.legend()
plt.show()

# %%
def p_value(lista,valor,posicion): #pvalue para ver cuan extremo es el valor real
    a=0
    if posicion=="mayor":
        for i in lista:
            if i>valor:
                a+=1
    if posicion=="menor":
        for i in lista:
            if i<valor:
                a+=1
    return a/len(lista)

# %%
p_value(H[0],0.5193,"mayor")
p_value(H[3],0.5277,"mayor") #Van a ser menores a 1/1000
# Out:
# 0.0

# %% [markdown]
# **c.** Caracterice cuantitativamente el acuerdo entre las particiones obtenidas utilizando uno o más de los observables vistos en clase.

# %%
def entrega_lista(Gr,metodo):
    #Edge_betweenness
    if metodo=="edge_betweenness":
        com = nx.algorithms.community.centrality.girvan_newman(Gr)
        a=[nodos for nodos in com]
        modular=[]
        for i in range(len(a)):
            modular.append([modularity(Gr,[cluster for cluster in a[i]]),i])
        modular=sorted(modular,reverse=True)
        A=a[modular[0][1]]

    #modularidad Louvain    
    if metodo=="louvain":
        partition = community.best_partition(Gr)
        A=[] #armamos la lista de la partición a partir de Louvain
        o=[]
        for j in Gr.nodes():
            o.append(partition[j])            
        for i in set(o):
            a=[]
            for j in Gr.nodes():
                if partition[j]==i:
                    a.append(j)
            A.append(a)

    #modularidad Fastgreedy
    if metodo=="fastgreedy":
        comus = nx.algorithms.community.greedy_modularity_communities(Gr, weight=None)
        A=[] #Partición obtenida con fastgreedy
        for j in comus:
            a=[]
            for i in j:
                a.append(i)
            A.append(a)

    #modularidad Infomap
    if metodo=="infomap":
        partition = clusterize(Gr, "infomap")
        A=[] #armamos la lista de la partición a partir de Louvain
        o=[]
        for j in Gr.nodes():
            o.append(partition[j])            
        for i in set(o):
            a=[]
            for j in Gr.nodes():
                if partition[j]==i:
                    a.append(j)
            A.append(a)
            
    return A

# %%
def diccionario_cluster(Gr,metodo): #genero diccionarios, para algunos métodos no hacía falta, pero unificamos todo así
    A=entrega_lista(Gr,metodo)
    a=0
    dic={}
    for i in A:
        for j in i:
            dic[j]=a
        a+=1
    return dic

# %%
def precision(D1,D2,Grafo):
    n=nx.number_of_nodes(Grafo)
    j=0
    for nodo in Grafo.nodes():
        for nodo2 in Grafo.nodes():
            if nodo!=nodo2:
                if D1[nodo]==D1[nodo2] and D2[nodo]==D2[nodo2]:
                    j+=1

    k=0
    for nodo in Grafo.nodes():
        for nodo2 in Grafo.nodes():
            if nodo!=nodo2:
                if D1[nodo]!=D1[nodo2] and D2[nodo]!=D2[nodo2]:
                    k+=1
    return (j+k)/(n*(n-1))

# %%
D=[]
for i in metodo:
    D.append(diccionario_cluster(G,i))

# %%
A=[]
for i in range(len(D)):
    for j in range(0,i):
        A.append(precision(D[i],D[j],G))
A #Lista de preciciones

# %%
#Información mutua
def conjunta(i,j,N,Grafo,D1,D2):
    a=0
    for nodo in Grafo.nodes():
        if D1[nodo]==i and D2[nodo]==j:
            a+=1
    return a/N

# %%
def info_mutua(D1,D2,Grafo):
    N=nx.number_of_nodes(Grafo)
    p1=[]
    for i in set(D1.values()):
        p=0
        for j in D1.values():
            if j==i:
                p+=1
        p1.append(p/N)
    
    p2=[]
    for i in set(D2.values()):
        p=0
        for j in D2.values():
            if j==i:
                p+=1
        p2.append(p/N)
        
    p12=[]
    for i in set(D1.values()):
        for j in set(D2.values()):
            p12.append(conjunta(i,j,N,Grafo,D1,D2))
    M=(np.array(p12)).reshape(len(set(D1.values())),len(set(D2.values())))   
    
    H1=0
    for i in set(D1.values()):
        H1+=-p1[i]*np.log10(p1[i])
    H2=0
    for i in set(D2.values()):
        H2+=-p2[i]*np.log10(p2[i])
    
    I=0
    for i in set(D1.values()):
        for j in set(D2.values()):
            if M[i,j]!=0:
                I+=M[i,j]*np.log10(M[i,j]/(p1[i]*p2[j]))
    return 2*I/(H1+H2) #Devuelve info mutua

# %%
B=[]
for i in range(len(D)):
    for j in range(0,i):
        B.append(info_mutua(D[i],D[j],G))
B
#Los valores de info mutua en una lista

# %% [markdown]
# **d.** Analice cuantitativamente la relación entre el género de los delfines y la estructura de comunidades del grupo. Puede utilizar para ello, por ejemplo, tests de sobre-representación y/o sub-representacion. Qué hipótesis puede aventurar sobre propiedades comportamentales de este grupo de delfines a partir de lo encontrado?

# %%
def rep_gen(lista,diccionario):#Vemos como es el género
    representacion_genero=[]
    for i in lista: ##lista es la lista de cluster en una partición donde aparecen los nombres de los nodos
        t=len(i)
        f=0
        m=0
        NA=0
        for j in i: ##Moverme en j implica recorrer todo el cluster
            if diccionario[j]=="f": ##Necesito generarme un diccionario donde yo ponga el nodo y aperzca el género
                f+=1
            if diccionario[j]=="m":
                m+=1
            if diccionario[j]=="NA":
                NA+=1
        representacion_genero.append([f,m,NA]) ##Me apendea a la lista la representación de género en cada cluster
    return representacion_genero

# %%
Dict_gen={i:j for i,j in genero} ##Diccionario con los generos. Le ponés el delfín, te tira el género

# %%
def gen_aleatorio(Genero):
    genero_shuffle=[]
    g=[]
    for i,j in Genero:
        g.append(j)
    random.shuffle(g)
    contador=0
    for i in G.nodes():
        genero_shuffle.append([i,g[contador]])
        contador+=1
    diccionario={m:n for m,n in genero_shuffle}
    return diccionario

# %%
#Corre bastante rápido

##Armemos el modelo nulo para la representacion por genero
Listas_cluster=[]
for i in metodo:
    Listas_cluster.append(entrega_lista(G,i))

Rep_gen_segun_metodo=[] ##Esta es la parte real de nuestra red para cada método
for lista in Listas_cluster:
    Rep_gen_segun_metodo.append(rep_gen(lista,Dict_gen))
##Veamos ahora el modelo nulo
iteraciones=100000
Rep_gen_aleatoria=[] ##El primer elemento va a tener una lista de listas (¿de listas?) correspondiente al primer método y así.
for lista in Listas_cluster:
    Rep_gen_aleatoria_lista=[]
    for i in range(iteraciones):
        dict_aleatorio=gen_aleatorio(genero) ##me genera diccionarios con la lista de generos aleatoria
        Rep_gen_aleatoria_lista.append(rep_gen(lista,dict_aleatorio))
    Rep_gen_aleatoria.append(Rep_gen_aleatoria_lista)

# %%
Rep_gen_segun_metodo[3]
# Out:
# [[13, 4, 1], [2, 10, 2], [3, 9, 0], [0, 8, 0], [2, 3, 0], [4, 0, 1]]

# %%
##PARA INFOMAP
cluster_uno_infomap_f=[]
cluster_uno_infomap_m=[]
cluster_uno_infomap_NA=[]
for i in Rep_gen_aleatoria[3]:
    cluster_uno_infomap_f.append(i[0][0])
    cluster_uno_infomap_m.append(i[0][1])
    cluster_uno_infomap_NA.append(i[0][2])

l=10
plt.hist(cluster_uno_infomap_f,bins=l,label="Representación aleatoria")
plt.axvline(13,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_infomap_m,bins=l,label="Representación aleatoria")
plt.axvline(4,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_infomap_NA,bins=4,label="Representación aleatoria")
plt.axvline(1,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
cluster_dos_infomap_f=[]
cluster_dos_infomap_m=[]
cluster_dos_infomap_NA=[]
for i in Rep_gen_aleatoria[3]:
    cluster_dos_infomap_f.append(i[1][0])
    cluster_dos_infomap_m.append(i[1][1])
    cluster_dos_infomap_NA.append(i[1][2])
    
plt.hist(cluster_dos_infomap_f,bins=l,label="Representación aleatoria")
plt.axvline(2,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_infomap_m,bins=l,label="Representación aleatoria")
plt.axvline(10,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_infomap_NA,bins=4,label="Representación aleatoria")
plt.axvline(2,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
##PARA EDGE BETWEENNESS

cluster_uno_EB_f=[]
cluster_uno_EB_m=[]
cluster_uno_EB_NA=[]
for i in Rep_gen_aleatoria[0]:
    cluster_uno_EB_f.append(i[1][0])
    cluster_uno_EB_m.append(i[1][1])
    cluster_uno_EB_NA.append(i[1][2])

cluster_dos_EB_f=[]
cluster_dos_EB_m=[]
cluster_dos_EB_NA=[]
for i in Rep_gen_aleatoria[0]:
    cluster_dos_EB_f.append(i[2][0])
    cluster_dos_EB_m.append(i[2][1])
    cluster_dos_EB_NA.append(i[2][2])

# %%
plt.hist(cluster_uno_EB_f,bins=l,label="Representación aleatoria")
plt.axvline(3,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_EB_m,bins=l,label="Representación aleatoria")
plt.axvline(16,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_EB_NA,bins=4,label="Representación aleatoria")
plt.axvline(2,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
plt.hist(cluster_dos_EB_f,bins=l,label="Representación aleatoria")
plt.axvline(16,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_EB_m,bins=l,label="Representación aleatoria")
plt.axvline(3,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_EB_NA,bins=4,label="Representación aleatoria")
plt.axvline(1,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
##PARA LOUVAIN
cluster_uno_L_f=[]
cluster_uno_L_m=[]
cluster_uno_L_NA=[]
for i in Rep_gen_aleatoria[1]:
    cluster_uno_L_f.append(i[1][0])
    cluster_uno_L_m.append(i[1][1])
    cluster_uno_L_NA.append(i[1][2])

cluster_dos_L_f=[]
cluster_dos_L_m=[]
cluster_dos_L_NA=[]
for i in Rep_gen_aleatoria[1]:
    cluster_dos_L_f.append(i[4][0])
    cluster_dos_L_m.append(i[4][1])
    cluster_dos_L_NA.append(i[4][2])

# %%
plt.hist(cluster_uno_L_f,bins=l,label="Representación aleatoria")
plt.axvline(2,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_L_m,bins=l,label="Representación aleatoria")
plt.axvline(14,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_L_NA,bins=4,label="Representación aleatoria")
plt.axvline(2,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
plt.hist(cluster_dos_L_f,bins=l,label="Representación aleatoria")
plt.axvline(13,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_L_m,bins=l,label="Representación aleatoria")
plt.axvline(4,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_L_NA,bins=4,label="Representación aleatoria")
plt.axvline(1,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
##PARA FASTGREEDY
cluster_uno_F_f=[]
cluster_uno_F_m=[]
cluster_uno_F_NA=[]
for i in Rep_gen_aleatoria[2]:
    cluster_uno_F_f.append(i[0][0])
    cluster_uno_F_m.append(i[0][1])
    cluster_uno_F_NA.append(i[0][2])

cluster_dos_F_f=[]
cluster_dos_F_m=[]
cluster_dos_F_NA=[]
for i in Rep_gen_aleatoria[2]:
    cluster_dos_F_f.append(i[1][0])
    cluster_dos_F_m.append(i[1][1])
    cluster_dos_F_NA.append(i[1][2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ce68ac8ffcb9> in <module>()
#       3 cluster_uno_F_m=[]
#       4 cluster_uno_F_NA=[]
# ----> 5 for i in Rep_gen_aleatoria[2]:
#       6     cluster_uno_F_f.append(i[0][0])
#       7     cluster_uno_F_m.append(i[0][1])
#
# NameError: name 'Rep_gen_aleatoria' is not defined

# %%
plt.hist(cluster_uno_F_f,bins=l,label="Representación aleatoria")
plt.axvline(15,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_F_m,bins=l,label="Representación aleatoria")
plt.axvline(7,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_uno_F_NA,bins=4,label="Representación aleatoria")
plt.axvline(1,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
plt.hist(cluster_dos_F_f,bins=l,label="Representación aleatoria")
plt.axvline(2,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de F en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_F_m,bins=l,label="Representación aleatoria")
plt.axvline(18,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de M en clúster")
plt.legend()
plt.show()

plt.hist(cluster_dos_F_NA,bins=4,label="Representación aleatoria")
plt.axvline(2,c="r",label="Representación real")
plt.ylabel("Número de re-asignaciones de género")
plt.xlabel("Representación de NA en clúster")
plt.legend()
plt.show()

# %%
def diccionario_cluster(Gr,metodo):
    A=entrega_lista(Gr,metodo)
    a=0
    dic={}
    for i in A:
        for j in i:
            dic[j]=a
        a+=1
    return dic

# %%
def p_value(lista,valor,posicion):
    a=0
    if posicion=="mayor":
        for i in lista:
            if i>valor:
                a+=1
    if posicion=="menor":
        for i in lista:
            if i<valor:
                a+=1
    return a/len(lista)

# %%
p_value(cluster_uno_infomap_m,4,"menor")
# Out:
# 1e-05
